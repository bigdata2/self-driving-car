# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

path = "/home/anurag/carnd/CarND-Behavioral-Cloning-P3/data/"
data_frame = pd.read_csv(path+'driving_log_all.csv', usecols=[0,1,2,3,4,5,6])

data_frame.describe(include='all')
# Out:
#         IMG/center_2016_12_01_13_39_08_300.jpg  \
# count                                     8035
# unique                                    8035
# top     IMG/center_2016_12_01_13_42_55_350.jpg
# freq                                         1
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#          IMG/left_2016_12_01_13_39_08_300.jpg  \
# count                                    8035
# unique                                   8035
# top      IMG/left_2016_12_01_13_44_00_503.jpg
# freq                                        1
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# ...

# %%
df.hist(column=data_frame.columns[3])
df[df.columns[3]].describe()
# Out:
# count    8035.000000
# mean        0.004070
# std         0.128848
# min        -0.942695
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name:  0, dtype: float64
